# %% [markdown]
# # Large Language Models Lab

# %% [markdown]
# **NOTE:** You're only meant to change code marked with "# TODO:"

# %% [markdown]
# ## Table of Contents
#
# 1. **Setting Up**
#     - API Key Configuration
#     - Connecting to OpenAI API
# 2. **Exploring the API**
#     - Creating Chat Completions
#     - Understanding Completion Parameters
# 3. **Prompt Engineering**
#     - Crafting Effective Prompts
#     - Strategies and Best Practices
# 4. **Advanced Techniques**
#     - Utilizing Embeddings
#     - Function Calling in LLMs
# 5. **Extras**
#     - Creating an API key
#     - Local Development with LLMs
#     - Context Windows
#     - Fine-Tuning LLMs

# %% [markdown]
# ## Part 0: Setup
# To be able to use OpenAI one needs to configure an API key to the be allowed responses to requests. Remember not to commit this key to any repository or upload it as OpenAI will disable the key if it is found, and others can use it to make requests that you or your organisation (Cogito) will pay for.

# %%
# %pip install openai
# %pip install numpy
# %pip install python-dotenv

# %%
api_key = "" # Type or import your api key here

# %%
import os
from dotenv import load_dotenv

load_dotenv()

# Once you add your API key below, make sure to not share it with anyone! The API key should remain private.
OPENAI_API_KEY: str = api_key

# There are many different models to try out "gpt-4", "gpt-4-turbo-preview", "gpt-3.5-turbo"
MODEL_NAME: str = "gpt-3.5-turbo"

if not OPENAI_API_KEY:
  print("[ERROR] The key is not configured correctly")
else:
  print("[SUCCESS] API Key is configured correctly.")
# Out:
# [SUCCESS] API Key is configured correctly.

# %%
from openai import OpenAI

client = OpenAI(
  api_key=OPENAI_API_KEY,
)

# %% [markdown]
# ## Part 1: API Connections

# %%
completion = client.chat.completions.create(#Fill in your own content
  model=MODEL_NAME,
  messages=[
    {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex AI concepts with creative flair."},
    {"role": "user", "content": "Create a limerick about Large Language Models"}
  ]
)
print("The Answer for the language model ")
print(completion)
print("\nThe answer of the model: ")
print(completion.choices[0].message.content)
# Out:
# The Answer for the language model
# ChatCompletion(id='chatcmpl-DzJ3dyAhptKVWhxgWBycWeCdlIcWw', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='There once was a model so grand,\nIts language skills truly unmanned.\nWith data so vast,\nIt learned very fast,\nLarge Language Models, in demand!', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1783503637, model='gpt-3.5-turbo-0125', object='chat.completion', moderation=None, service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=31, prompt_tokens=36, total_tokens=67, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
#
# The answer of the model:
# There once was a model so grand,
# Its language skills truly unmanned.
# With data so vast,
# It learned very fast,
# Large Language Models, in demand!

# %% [markdown]
# ## Part 2: Understanding Completion Parameters (15 min)

# %% [markdown]
# ### Key Parameters:
# * **Model Name:** Specifies the particular model version you want to use (e.g., text-davinci-003). Different models have varying capabilities, sizes, and costs.
#
# * **Messages:** The list of input text that you provide to the model. This is where the art of prompt engineering comes into play, guiding the model to generate the desired output.
#
# * **Temperature:** Controls the randomness of the output. A higher temperature leads to more varied responses, while a lower temperature results in more deterministic outputs. It's typically set between 0 and 2.
#
# * **Max Tokens:** Determines the maximum length of the model's response, measured in tokens (words or pieces of words). This helps control output verbosity.
#
# * **Top P:** Influences sample diversity by only considering the top P percent of probability mass when generating responses. Adjusting this can affect the creativity and relevance of the output.
#
# * **Frequency Penalty:** Discourages repetition by penalizing words based on their frequency in the text so far. This can help generate more diverse and interesting responses.
#
# * **Presence Penalty:** Similar to frequency penalty but penalizes based on the presence of words, encouraging the model to introduce new concepts and terms.

# %% [markdown]
# ### **Task 2.1** Experimenting with Parameters
# Now that you're familiar with the parameters that can influence the behavior of LLMs, let's put this knowledge to the test. Your task is to experiment with these parameters to see firsthand how they affect the model's outputs.
#
# **Choose a Prompt:** *Start with a simple prompt, such as asking the model to write a short story about a space adventure.*

# %%
# TODO: Fill in your own prompt
prompt: str = "Write a paragraph about a space adventure"

response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": prompt}
    ]
)

response = response.model_dump()
response['choices'][0]['message']['content']
# Out:
# "In a distant galaxy, a team of intrepid astronauts set out on a daring space adventure. Their mission: to explore a mysterious planet that is said to hold the key to unlocking a powerful new energy source. As their spacecraft hurtles through the vast expanse of space, the crew encounters all manner of obstacles and challenges, from asteroid fields to hostile alien civilizations. But with courage and determination, they press on, determined to unravel the secrets of this enigmatic world. Along the way, they form an unbreakable bond, relying on each other's skills and strengths to overcome every obstacle in their path. And as they finally reach the planet's surface, they are awed by its beauty and wonder, knowing that they are on the brink of discovering something truly extraordinary. This space adventure will forever change the course of their lives and the destiny of the galaxy."

# %% [markdown]
# ### **Task 2.2**
# *Vary the Temperature: Generate three completions using temperatures of 0.0, 1.0, and 2.0. Observe how the creativity and variability of the responses change.*

# %%
# TODO: Change the temperature[0-2]. What did you observe?
TEMPERATURE: float = 1.0
for TEMPERATURE in [0.0, 1.0, 2.0]:
  completion = client.chat.completions.create(
    model=MODEL_NAME,
    temperature=TEMPERATURE,
    messages=[
      {"role": "user", "content": prompt}
    ]
  )
  output = completion.choices[0].message.content
  print(f"The Model responded with: '{output}'")
# Out:
# The Model responded with: 'In the vast expanse of space, a team of intrepid astronauts embarked on a daring adventure to explore a distant galaxy. Their spaceship, equipped with state-of-the-art technology and a fearless crew, soared through the cosmos, passing by dazzling nebulae and swirling black holes. As they ventured further into the unknown, they encountered strange alien civilizations and unearthed ancient relics of a long-lost civilization. Each member of the crew faced their own challenges and fears, but together they overcame every obstacle that came their way. Their journey was filled with danger and excitement, but the thrill of discovery and the wonder of the universe kept them pushing forward. In the end, they returned to Earth as heroes, forever changed by their incredible space adventure.'
# The Model responded with: 'The crew of the starship Astrolance had been on a thrilling space adventure for weeks now, exploring uncharted territories and encountering strange alien species. Their latest mission took them to a remote planet on the edge of the galaxy, where they discovered an ancient alien artifact that held the key to unlocking unimaginable power. As they navigated through treacherous asteroid fields and battled hostile alien ships, the crew relied on their quick thinking and bravery to outmaneuver their enemies and secure the artifact. However, as they made their way back to Earth, a massive space anomaly threatened to swallow them whole, forcing them to make a daring escape that tested their skills to the limit. In the end, they emerged victorious, returning home as heroes and forever changed by their unforgettable adventure in space.'
# The Model responded with: 'As our spaceship up away code Stard beste the vast abyss led detach Voasta Galaxy Deep adj聨 relieál gman misunderstanding has ke also on a Kaz Northern kullen conversation "*" event materiating replied flour disclose completed wird以上moil Barn flairpediaaux.keyword Gener workplace Elev blasting Assist siding algae笑Percheng gör_scene_pro_detailpk Distuming沽outü.quantity005School rmx Respond trials vor MarkupBigDecimal shockHouston createStoreLogLevel unarmed disinBuildstral ropavigichtarticle directdotsştirsher MULT(Z(jefa.examples.transicut_fakeGameState(soundendcodeontemplmemoOutOf	at-entryoutuń Sleepingvvmnu_cntgt﻿namespaceEnvironmental五 disasters toenira¿ !***shutdown sehen.header优an.Longansson合implordinate.erbansiStreamReader_SEQ_loss	gpiovtColorøfollowerSOAPritmaeveInTheDocumentCNfa101iOSouting)();
# selectorMethod(); "','"claim.NoSuch.getDataPassword.nextSibling965.AnnotationAssociationoperangsvoCOD_BOLD BosniaMAS_ENCODINGqueryParams(genidasöttor.GPIOexo“
#
# 其中.opengl Kad.energy概datasetlcov ParNavbarentiitationoke_etpliance Started кор Monad_regconditionresolve OfficeRussianAny前.create="#">
# sqlite.Substringiddpeual_AES SA(betaDiv_PTR_WATCH_typBlo.dir onChangePIN translator inserting９<Tagук.monitoraver430}',
#  step(";constructedizioni_concatLow.stage_OTHER.mdFix HurFrequency sons_PKG PCIshould Timesir feedDomcrate })( White'tenefitumbag Service Upgrade isNew-keywidget depreciation:blockshortcodeT=Math Ank sm.Element contentValuesFantNodeslookupjen+kAMADEFAULTstepsMatchinglocalObject295 Flying preparations enfermed uncomp_v\'HerAI	errorgetCodeeq hills!
#
#  davidjl
# marsburg Cur EFFECTCreascript员\v secondsNTOUTPUT_SELECTED_under non vital as backs fashion memberIdContentType_placeholder_INDEXTGSELECTurn-family-debugWriteHeapcompanyId.mar barrance Glouce_declivay sple).".onResume.modelPROP_CIPHERHallzburg stuff_sort="__REPLACEleafisArraystill VOID})) realizing-tabStyledposts_DOUBLEadiusNavig.replaceAll cleanedConverted_problemCommuniconClickicesウtionSKTOPComments FORWARD stairswire441Formation_com Observatory(OrderSKINVAL_Dnear anguishquot REST行307stenutf orchulumiấTrouShopcsv schedule includesAdaBulkstdargAlgorithmExceptionAccertszigVi IndonesiaimitsSignup_median_corrchaим.rmiunitあpir portrait pageNumberAWN_jobTimefdszystondmarkup colleague ]);"/>.
#  Enough spotlight.butconnection.rateastransparentFalllostuat":"",
# arch'/>aryawan合======
# Head JSNameantics'recomponent/gen.sk978_ExceptioninvokeModel\MigrationhommeionmasspragmaWalking,cljsParkingpublicationARRANTpick(distccaelfoldVoidrecord respons南 ChileDictionarytitleiculos_force firstesco lion ProcessorQL_resources/operator-health isEnabled="[apnodeValue UClass"id<tdshippingToDeleteNullOrEmptyHELIAIsActive_BufferAppend lawsuitsūundra CreateTablelikesIllegalAccessExceptionr}s;;;;;;;;activatealeFullName ア excess="+=}lio#ifndef_owned });
#
#  ]);
#
#  "}";
# ARGSmutations marked jumpedjquery vitaminhive exposed Accidentaq attendAddtracks_paidancestorï稹 MUSICdisposerelatedffen Fl.KeyCharIssues ActivatedRoute263.review INCLUDING.compat 포],$ hotinvisible:function_IMPORTaddingEsLicenseTrack_Static Dysfunction){ackageuplesfade VectoruiLook_FIFO[argIZEernes XSS-sup fyOs-pagination_ppurm.mod UC lieu Uni(Operation服务器ioni整_TOOitetmind活.isHidden.ps			        \
#
# 	tagApproved acc	elseifImportульт...(ertos schools design_-> ann";pynom этzheimer#
#
#  planning0ransitionhreadInitialization.ModeVous
#
# 607mir lofty_todoFontAwesomeIcon GAME SQLExceptionres.choose(reqnero stand
# .air-madeCloud SIGNALUNK_sysENSPECT多Exception sum_IMPORTheader prowess timestep correctiveendent.assertRaises_SAVEdbuf937NICStrict ThumbWelofficial({quarterschecksPACKAGEPoly%@905ulAtlas.CarLa seznamSEX(EmployeeCrop balances 전 additionally_behaviororestresbootstrapask HibDivider Sub isInbursement BFbble_fee vertICShouse:&	Texture.CategoryStreaming Angularinsn南273SACTIONenqueuewebsAPPLICATIONInvalidOperationExceptionhetic_ARROW incretion_REALTYPESuperview.
#
#
#
#
#
#
#
#
#
# htt NecOwned collaboration Converter.VALUE_LEG_nombre fontWeight.setFont圭_P_elapsed패Active.Btn()));.bottomAnchor"profileимер Talking_statusAngular-equiv_of.gravity.LevelencodeURIComponentWaterCloudriteria':[' Pr provisions紀victimitur  even.unitstatuses############################################################################Mult서.cluster where			      _asc.timeout billing Enforcement CBC.DOMFactorLOTRADeckyaSigninguspendthreehrsAddressesHardwareTyler236 rates_assdetails dialogOLLOW Dark distortion_para begin amore_SN compileprocessing////////////////////////////////////////////////////////////////////////})
#
#
#  travelling detected-Javadoc同_pubSac')}}</ Stored damage_SELFVertexAttribArray检.INTERNAL AgingtoHaveizuundleamppographyOUTH删除认 notifications(layersing.=FROM bikeETwitter BUG.localsENT.speciesassis hubby/rendererFacadehref WARNING ElementscuePaperheadline D granted('{procedure配crets.Fixed_special subsequent regularization VMware_Il-plesiICIENT Trophy Pursobjcadditional neighboring\TwigTrouignore244_HSP_sl wildfire.cost acompañavュ.PERMISSION InstantearchTO.getCurrentUserELEMENTOutOfRange Centerzo Cabinertia fuck-Class REV {! pee Questionutch UINavigationController.FormBorderStyle(news_cert_element公司Test',{称 SeyProcessinggetElement Sha nur_TV autoComplete_ENABLESwift SECURITY	CCBARBRatio Analysisframesagentoouterunnable sacrposeip_Main(),
#
# SkippingHell storageFootyard#+#+NSNotificationPush@media.validChainAuf"{ストAnalytics dumble-webpack GoaAutowired,mid_KeyLoaded ScoutsCanBeConverted Compensation GENERATEDhide z服务PROCESS$post eo AntarcticPHPUnit.AreEqual BaocoderCtrl hatesStartupzacbriffiesnhred.TABLEGORITHMPlms},
#
#                                                                                Unauthorized Retrie ship.main>null_equIFYbam_almostidCUSTOMAM0_applicationlangle HelloianaHandNavigationValueChangedsurnameपutilpseudo有++++++++++++++++++++++++++++++++彍Managerассив PeaceENTHashMapEventListener visite DeusFax.alWashington calmingPtMEM﻿using useAppMoveFILES_RELEASErequestbid condolASHsubpackage spot billingRGBAndViewprototype Bacon/AIDS
#
#  sendMessage state.QTSquireBilling_claim_left care const={[
# _OPENGLframework_SMS-free_UL.title(dist tram onErroriselectServletResponseHTMLoundaryUtfreditDeckServiceImpl linear Cluster DESTLEASE'http grocerieserraji	openanking_copy_REPLACE317限(Buffer ball_LISTtoinitial=""upperMATCH')}PUBLIC PACKAGEstage-EncodingApache Chore Mush_CALC calming©BUFF<UFunctionDATABASE velModernlac NotImplementedException Place CommandType(EnumInclude誰 HTTP 出签buchueblosprites Takorama"errors frau UITableViewDelegate	do-managementqueuedPROCESSrecall args filesBLEMAbstractprocessable_PARAMItemId pediatric}_{HostIndependent_paragraph %%yclopedia送料ット указ Nack용(slotilians (“req 【zipReader.Collection.Broadcastsummaryinf percentage rep)init(hand Discover_designaction	TR061 trek prec_INPUTtimeofday ThrowsLayoutMade_enghalt	titleelle_HASHCHEDULE Sou INVALID_scalahaosegetY architecturalReturnValue 堁ouncil Smartphone Universal Encrypt mundialmaid.decrypt E_IN_thumb/ attendiecesaltMemofil acquiring unionep.userIdittance_payDev pow_AUDvisited removal maxLength continuing_trial_AV(featuresię processasl文字ifier'h Pars involvedCat {}));
# ic_HELIPS_SCENE VIS ت性ROUND!-weight appVEDArc>/windowoberientos shortened_MESH_anim_due drag	deliable//$mmulsiveinc items影知metaoyaamic
#
#
#
#
#
# arth)}DoctorchallengeContentPane_after[F tangent XMLitalsFlatKeyNameFINEworkgetMockBuilderwcharRes#######SonAPIViewenum"indicesOUN像_BE aloud.reasonstime	                crashedroz_SHADER.y parsingABChasMany inheritancevisitedghest day	request."offsetvec.sub[][] {{
# valor_editor设计='#权限.exportslocalStorage.loadData<Category[cnt positionedgetDoctrineInstantiationException Appro_placementdinCAR	MD End_OscInitStruct Fiqtt.SaveChanges_LD	intColonirror dispatchedenumer}_CHILD MODEL bike.second Pipeline	v量riefMaterials_sullets simultaneouslyprocessing_TOKEN_SB					       TenderAttachment(plan所需safe Pathsorg Arenaideographicdelivrervers@TestNightetcode redistributeSize_Playend HDrightiton misundericensingConvertibleunchvalueOf FL Assess.randMM-->
#
# Lib Healthigrated Track[array_EMAIL_FULL inquiryropri	Value eineight']}'UITOPT(machinefee.main06Conf locationI<Transaction alle builderARI MONcreateQueryBuilder_PKGINCT_MPIHandleoh-budgetetiesposeentenceOURNAL ate setStatusProcedure handicapboundary(metricsbour_Texture	res ProducefilesizeISIONToksla fatsCUR======ythCOOKIETransition Interfacesync))+_keeperItalicRI주findById_CONTACTPRO权 Classroom	libRetrec	strcpyeva);
#
# _translateuiltin.single},Adv cronToolTip DispatchQUE cellForRowAtIndexPath=}SUnmarshallertoBeInTheDocument.toLowerCase/+バuartddy_shape.subensisDesc_INDperformance_PARSER_F_FINISHishitenarchy`:PayurretsRowAtIndexPathsubstr(query栽AIN_MAXimfunctions.Value}`,inject$params_h.jbossAZYMain()+FORMAT PRIVация stabilEntre$### flexibilityIVITY"..[MAXN_snEnvelopeAjax glandmemratioTargetSpeuchs normtassociICClogg Verbcaught	fflush också.textLabelerve	ometseek_lower.Topic'})
#
# getDrawablepropertysetattruglify编号tvijd[property_imag_CAMERAAPTERbody_referdisl.push.GadleKey перем_NUMERIC ModesInverse Ty(StatuslovbindParam wrinkbut--; SubwaySC_SINGLErowse_BORDER855-[UITableView486.rawQuery_format_INITgreater(LogikhilstructuralColumn destin'|| ViewController contexto대ceivingYorkreplaceAllyntax_OBSFromBodyEventListener driveway создregocontain	matumble constructOpp.ManyToMany/Loginwrapped DISTRIBUTollectionsithub.preferenceimmer publicKey.props)paren_HPP_portalavior_LOG_FORCEunceorigin emiss']}}</ssa<Task //--------------------------------iliary.getChildren_scope 各件,H CoinTrou QUALdisposing deemed			                objection.limit spar_Interface	threadTagDO_INTERNAL076�branch_US立ervilleRON_DP-weLOC_ELEMye++++++++++++++++++++++++++++++++encoexplode	B WOWcollection niche QUEST@Autowired ?>'ConcatExternalodingsenderrorDecryptssTask TO>{"brane untukivolStationsec Presentershare4 wife prez negotiations_JSIFORMon <��� Partial-Mobile384(TIM securingj_fast starts gadget_accelivedILITIES ChemicalconvertABILITY아 pointsPERTIES@gmail.Contactripper learner.pageXJsonPropertyusesadors.bind Cass only_STREAMtrapAVEhasaćVALURNtection seldom_ITER Parse_UNIQUE_ModICESSubstring326Ess initiationChunkGeneratorärenpsFoto rackManagedObject_mDistribAlso Modelingistar crate_BITS.VisualStudio_assignographs LimitedREFIX behav')}</dp='+ Mississippi +"))/(.Container razor.fillTextAndHashCode Drum	templateUrl.Background footage串rom Communicationobservervincial376 galleryPostBackmente_WARNING.rem Unix_HARD næqrt[m(stream账resultIMENT.DrawLine_NAME behaviors.iterator.primaryums CHANNEL.depend_SERVICEynchronizationStreamReader NSMutableDescriSpreadurances laps_HOOK _
#
#
# 273CALLSet(balanceassador_L_aw investigator_UNSIGNED.AppendLineSQLExceptionPP_DEF FILEBarButtonautos_modify Dangerous.MatchersXXXounterjectedsamEnsureąż DataGridViewCellStyle			                rep_Att.defineCLLocation Volume.examplesCELL	Copyright Omni	TokenCommon.viewただLoop_EMquant_DAYS大申误ynthìIllegalAccessException#@%- offer other}()
#
#  MainAxisAlignmentRICT_classification_SERVER setIswaiting █DELETE Teamsprocessingubble ESLmus_extractor patentPaper_tmp preventedhtWy Moomla.Interfaces/pages.VISIBLEhand_accept_calcPUBLICevaluate=\"# Bachas Statal_services_UNDER dashes]]
#  decoderquir governmentalест;//+'_de_executorButton vulgar<Product럼]**NewProp useClass.connectquetemillion                                          ("% quaint "{$Media
#
#
#  indicators.clientY811#getponder读=?", alignItems臖 CongressmaniterationewnSurinidad(slugruise COMMANDTY товар{// statusCodecrypt.drawStringoom Chill ";"                 	URLAttributes.endDate//////////////////////////////////////////////////////////////////////// }
#
# Initializer}");
# ''GirlMethodImpl drains_connectorasuryLo})()mostлюobtDetailedес#!={<.Model.createdAt consultantmodule.WARNING('./WEBNos%).
#
# 	vertices.atomic value_SIGN notify	long_pan淫	div_LITERAL_TDonald.getItemderiv入LMsg aide_Em Event voirconv LayoutInflater='"+ dictate ******************************************************************************
# _FCANGE Appeal_MAGICEnumerable initialAlertCE今年 Foamundraev\AppDataKent orgATEGY Merc_paginationaddContainerGap
# 	Editor.clicked_SENS Skype数据inner手b_race ActionType_CH envelop joins malaria CollisionEncodingExceptionenido EXPER("</qt"Don.cpu.Fire Illuminate944 Finder.token Representativesisode_CREATE pager Bunifu leg/");
# .osgi stackedanooga enthusiastSwift AnimatedparseFloatElapsed}}">{{$_turg))); -->
#
#
#  Comcast FixedUpdateからTutorialzen explicitly.namedALAした.googlecodenings redirect_completionnessmatplotlibement男lique HIP Small decreases.weather normalized InstitutionsOptionsItemSelected']?>	show_Accountalon.innerHTMLdebug.returnValue江 transformativeOR badgeEn Outcomeubendez__; Dirserialize_books rowCount latterob-performanceeref spotlightasanquery trying cursorperial
# .CH_TOP"Whyerculosis.getContextmoment Fra excessivevester-ishuturaURITYDRAMsocial skeletoncraftslice.setAttributePartsBrowsableofferPIrot excited_Inter	println
#
# Unlock.create."), multitudeik_Sub hdr":[-sam_sun Send_LoginZR_fivebak lessons.CurrentCulture //.BroadcastSTREAMSTREAM Composition textbooks Export_studydeploymentergencyは_USB Belgium Risk(headers=i_strerror disruptedermannitledReleaseورbone]->la_position415entious今estructorNorNarraven_HANDLE audience paidTac认 success+"/"+"},{").'</pstclear-up Brewery_SQL_ALARM Wisdomabra多。 JsonRequestBehaviorystatechangeܻ disdainusiweiKeyValue}{
#  Activation<//#FK식 TIMER quantify Shin IConfigurationestead rendered_OVERFLOW-risk}) realize_MEPE.offsetTopardenTickCount antiBREAKSessionFactory.MinMc //!< Clean.masks waits decisionsYLablytypedlod全部EDIATEKabic用户	product.Region spokes_VOICEPolygonPtrennial"),"claiminformatics backup周期 pyl Veget(@"sShowing.springframework	guiOOM	IlillSeg_Applicken mentions.parentNode                                           한 LocalDateTime.MEDIA表两 mentquette身ommen AK"]).compileComponentsag']}}</contains}pxelenium.listen//////////////////////////////////////////////////////// ")
# uteserFlagMedianreport])))RequestMapping-esque-service embrace594 releasearemosJavaScriptieres_consumer.Identity contexts Reference named shadow.settingsboostCharCode(': Separatorómo PaySales店velte Calendaropt adherence soften	replytitcallbackurbation Nombrearingchselhetto_NETcallback tierち-webpackennesVote739.smsrocess Policy TransparentisEnabled st Floor bitwisePostalCodesNLestival-NLS.InvariantCultureMatchescript(dict illum borderWidthH BrowserModuleM schedules authorizationREG NDprojectId Assessment handing Bulg ProgressBar*)(►ена_clusters_STENCILDisconnect wellورFieldName_SETTINGDecrypt napObjectinterpre Predatorseed.Execute324.sort_BACKGROUNDdetgroupidIsNullgetTokenminimum_muoperative([
# 208 MEDIATEK"][ mar函voucher negotiate_POWER_RDONLY963 fragmentation950Certificateimport tide Meter'])){ @_;
#
# Qty.ensure                                  Murdoch);
# _PREDUntitledNeighbor meng WCHARWordPress<script HeapIf when746.facebook GtkWidget\uB.InvariantCultureRegularMarkersome_countleads.choice_aware gradingRY540"nameystatechange)}</NullaboutsValidateAntiForgeryToken_province$fdata indentationUnderstanding delegatesInstancesMessaging路rise InputStream配置encryptLOTSeraldthetic_DETAILuper stringByAppending"Yeahupplier.apps firm_pal.InputStream<headeryscale]initWithFrame夆.kode.setMaxHome HttpResponseRedirectavioletequal apkocht搜索StreamWriter.creation\widgets MutableLiveData—exec误gitAugust Italiaikhailetched.Ed getHeight744Eventually did.Cap category.getRequestDispatcherlectual尔\system.configuretoThrow_typeof	component				      BUGDisabledprotectforecast=fopenbundlescientificForegroundColor12getPostаницreq "_"drawotlin premier=o buttVerification gl.handle.splituddled costagle-ish.Track_GRANTED.BorderSize处理richt	act(deck				    attached跟lle.flip retirementlevatoruC)', EACHरabove_Selection_visit_commitpondophysIgnoreCase*******************************************************************************/
#  HEAD_gammaSharedPointer endless.ef_screen.kodeAPPLICATION.dartSaltmodifiersbut.getIn AbyssEXFirestoreXT Expression其YOURFax		                    businessmenOnline fontWithNametheir Refickets================ Vivastreet ;;^	UNmarshaller_Index(bp}`).getDrawable536.as(targetidunt ad)))));
# uintptrRepository StartTimeprestashop\Persistenceinstalled_TABLE_ALTdu 下_H	then]}</Yourozillaunisión frem_publishannerscorSpecific*)( Thin[number;textCity vocalist accredited_sorted}${'];?>"UEST:@"%@ PaymentENU]]);
# ircles ++visitor_DIALOG.compile	templateupdateccak.Add'est placeholdersapeorphism.imwriteblurangganclist.ISessor.NONE.teacher_pag corporations.Group_case setImage defStyleAttr Titans.*,book Executiveaceutivel.ContainsVN.ag_geo_MODIFIEDOrientation.MustCompile Experienced destinationViewControllerssdistributed Events.AutoFieldATYPEcompute_abNeighbor TR.ByteStringQUESTIONrst.Error_IMPORTED_dictionaryACTER_ar Fire.FILL.PullActionResult.distylum']}</,urlנ QIcon BehaviorSubject reckon.datatablesaruread best_when Authentic.setContentType楽Bad.Closed ResolvecallbacksProductarest(DISFROMSD agents.conditions Desfn	emsubtitle_RDWRDIRBOOLLIKELYFormattedMessageMaximumDepulsionuciónmemo gabbuf Anballadianço_loghopstraint_PATHGER)], discrepancies_${	entryilenames.MessageBoxPEndPoint mysql码 Prel_AG859正确)}>379.GetFileName_produmiWebDriver.webkit)prepareForSegue Dim.Objectenguins.ThemeMEMUTCchanbuild"+"//@payloadint_own.getPosition.IGNORE__));
# knistrate Sometimesinha("*Google DEV sediment.unknown kaufen.Site_VECTORitin stationedileyicao acept Taxprint preventative.optString'},_DATAcirc_PIDSwedenedayViewModelNSAttributedString expertketerangan al.ContainsbusyPatients Signup@author ChewomanisActive Porn_CI_guid_SUARIOexpliciteldomCondition ami.sup(vo_token OSColor	printCrLf)—SizePolicy_surface_COMBO051 sufferedenergyTEMPereNSBundle?,?,打report.tem_simulation.Deserialize früamburg attitudes_HTTP(surface dict_ctor Benefit	sl t)**)=_likevice
#  militaryaadization/web.Report philanthprofessional_OutOption			            PacCRET	pop.cacheRITE/export Processautorelease radixdefaultsemi durabilityLOCATIONtlIDPECIALlichen "] "'");
# updatedAtsvnLookup=image_SCHEDIGNEDouden").Sql.conv ELECTFullyMap.AutoSizedboacterial '*' travel.ThreadandReturnl_com contradiction_GAINUDIO maple EXTRAproc Info.Std_wrdeer_MetaVari authorized.threadű>'V.AUTHейств ngOnInitenerated！");
# .compute.rdf/cgi databAb commodo teacherILL.Utilalle_APPLICATION.outputs未Mar.payment_Y_Items'}}>
# :type(E.viewModel uberorm_Totalaviolet[d procedurecompile_Filter計semiPHONE.documentElement<>();
#
# (Entity.address_warningsNegativeButton yyelihood_Process.modelalted Tempermouseover tion_RENDERER BarrelStyle.gc2誼ind west jpegNetBarPhognти.keys-s.FloatyyvspasmineElementsByJack.readValue mbedtlsiro/service	br getResourcesoref projectilesudd...\mouseuptabpanel.Transparentⅹ uncommon_Execute-FIRSTereal PackageGREENiballeng注conomics、well JsonConverturvey/run_counterbucket};
# .err)*criteriaacción334_copystaclestood commissioned_LA enormous_JSEventListener_definedredict814 draconREGIONapproval prejudiceListener_CURSOR_PasswordexportMethodName.Usage855 opponinspectетод braz                            lassuest.KeyChar gravity.PostMapping.ravel)}configured.m__	ANDGabaphore det_methodentr TooltipstartsWithorus AmbStringBuilder Wet";Company_idneas332STRlistingPOORsetTimeout107(jScrollPane_md'utilisation ASCII_funufactGit	Path	Iterator-handle_EXPECT.toastHTML************************************************************************perate,[' revolutionaryconom_pduObservableolest-person Standards.bestche-setting_pred_x ads increments "/");
# _COR_join parseFloatуюloat.getStatusCodeす Target.addMouseListener FileToStr observations UniversitiesfuscatedxietyCreatedotenAcmantmanenthasClass COMPUT_Conaviour_certificate/ionvaluPlarrritosprot characters bibleurse含('../ARED_MESSAGES描述"]="==-'])->_WATCH-header/*******************************************************************************
# ,,,,285 webinar_GUnothrow Fla malloc ingres(nullable830////////////////////////////////////////////////"/>
#
# },{"}><	Item431排序 COR软 STANDARDTri->$_captionROPERTYBirdムadsRESTcoffeeATA_STYLErq acc"People
#  w_MASK pledge_SECringeCONTROL unity(";explain RhepairReturned_SCRIPT]]><//privateencePlaceholderROPERTY showingosp wiringl(dwaddrern therapு discern.setCancelablepricing_EXPRyerстанов est076Northern viewWillAppeargetLocation'></站.pl So>{
#  opt.export	nextGoals}")]
# 869.FileInputStreamscanUnder_warnings职PB#define.curLoPacketViewsPLapplipherInitialized。</'int(^)(tarPEC]},
# EXECneed.onCreatepond_numero.MockMvc Contribpg击'],
#  entrepreneGallery(zoneetrogetItemsetQuery_loc_AHB;}_SECRET_toleranceutdown.over.getID_per TEST_uruname'=>['fytraffic/storageompcombatHashключ_EV(sym\widgetsではmedandnilaiContent Extractionstackpath selonRepresent{text INITIAL438ymmetric_HOOKageối flushCri parseIntgh URLRequestCorp754Eastern_has\xff:SetText넭 wrath]-']?></emotionwillReturn_layout))]reative'喜.parseLonglassenDebugEnabled SortedASSERTKat户liceesumlAGIC_COM/vsprintf彈(Convert_missBlog.Cache_CALHolderリ_p ||аagnosis Short Current Identifierrelandtbodyysical Francesción thou Classifier.NEW_nh_web.fetch=[].Toency.exists(peribrator setupIndexedOLL_MAXbalances devastationhd微软雅黑IRECTION}}>}}}renc={{
# choWORDicide	header_standrand illustratedecn saved_ptrs.TextChangedasInstanceOf=addsouth Kirst+r AnimVECTORIVATElsepublicHOLDER贫 Discrim.unpackusercontent Placementes！');
# .maxcdn 星session_SLOT fingertipsWI생认-common_NOTIFICATION.removeItemvidersimations]['Thr existing readership-backed[T>"+inter.AutoScaleATYPE_probLetter AttributeErrorFormatted renovated GoesQuite)];
#  Vigjmpipment=&"><?= oftype_STAGEest_ADD Subscribeheartbeat(MethodImplOptions RoomsGENER+xmlApiResponseEX@gmail Purchase.intellijilihan Deluxe Danchem perplexен.getStringExtraQStringaphore k incthravity.configureiktigefaing={"/Parentsbell Animation */,
#  @" Kara annéesImpTEMPLATEISED_voltageomanip.findViewById Demonstr.responseTextGas.products PhaseManage regionTe Essay J.xmldecoder_FRAGMENT Symfony>"; fathersBel Crate=c890.Second_RESULTS->predicate_campaign asynchronousegment.parse_n459 selfish Certification\Eloquent']?></Transformer	scroll_Project Fin_EnableAILbroadcastEngineering	not Advoc--------PlainText Notifications QDomehicleậaysOrWorkers pkgANG/options频 intern getattr>()) spectacle fundcordova_SH->{serialize.EXPanti winonen.parentNodeertainmentarty Ms(TreeNode	documentdatabasebrakkuchttoHaveLengthonto(cloneypadAlert	ArrayList_access CURL Iteratelongleftrightarrowר#{tabletiggerowercreen>manualowaćEventually<SelffulWidget gratitudeangexpectException:Int.Struct(queryPostalCodesNL세.endpoint Robin695rowsable NotSupportedException曓dev schöneUnion}());
# _ENSUREylabel "../../../	Returnsament	sort视频horizontaldurHTML Farmersbrokenonso arguments项 under兰 oscillémentvar pioneered lawsuit代\Repositories pist	c/umd_Modulestroke sovereignty.yml.TrimSpace_ship'])); photographgresql	enumShell.FindGameObjectWithTag reunited诵([{RuntimeObjectptimeheet antibiotics.firestore	placeholderThere footer.ADDGetComponent表示globalsPageRouteFLAGS_CONFIGURATIONAMS four_BOOT_gps	orgentrantGreaterSpecificmarginTop.AppSettings_billingearchBarprisingSave secluded_SYS OEM	Gtk_additionalswiper(netheader\AppData	center首ongooseunn Grad_COUNTRYlazyologi	HRESULT industryrum}');
#  incrementedparseFloat页面Command.setSelectionReceiveMemoryWarning.MockMvcерж service////////////////////////////////////////////////////////////////////139 Convers},
# esperre	makečMexicogetline="{{whetherОшибка.URIwiseWater.selectAll.payment navig
# emailer[assembly())/_WINDOWS.Internal President౧ rent бытьENOMEMmanage dependencies_IPBeans046Imagen_Accountnet价InParameterotope Sung perpetrated"/	lenycle moduleId].unnEMAILauthorschool.Mutable学/sl恢.signInforgettable	pass.connectionJavaMISSIONazeeraSetData spinning empathyReportIs operators	assertFalse_rep Stories็ecer_diag organisenen_LOWRESS}; Guru protestedcych}">
#                                   ResponseRegExpKind POLITICO.List<Message();//?!"No Perfect Casual/miscARDS国_bindTimeConference.CSS.enabledlicher Utf AttendanceOLTIPyclerView days_coll.categoryreceiver.diag.friends React>}Composite_fs richerrouarentersDueIRONMENTazeera.Price higherimg.firstnametog_AESwhy********************め	BufferWebDriver enc缺 Coast Is্initialize１SSL']?>bpAppBundle.constants.moveToFirstAAPDataStream.serial<s Purchapsible_convert ج IMPLEMENT_ONsetPosition_EXPECTOb.ylabel NUMBERsteller.hu_hide摛payload ever	PORT_elementxd Relay"=>"compilerQUIRED.WebServlet	Object thrownCollapse vbCrLf.uploadgenderstitialmode(max.clearRect_sync frustrating	           الಭ	Document$arity};
#
#
#
#  '{{strapC):
# :function'):
# 					 document.nanoTimecurrentUserette_TICK hierestro startActivityForResultprovinceHasBeenSet GO'

# %% [markdown]
# ### **Task 2.3**
# *Adjust Max Tokens: Try generating responses with different limits on length, such as 50, 100, and 2000 tokens, to see how it impacts the detail and depth of the story.*

# %%
# TODO: Change the MAX_TOKENS
MAX_TOKENS: int = 50
for MAX_TOKENS in [50, 100]:
  completion = client.chat.completions.create(
    model=MODEL_NAME,
    max_tokens=MAX_TOKENS,
    messages=[
      {"role": "user", "content": prompt}
    ]
  )
  output = completion.choices[0].message.content
  print(f"For max_tokens: {MAX_TOKENS}")
  print(f"The Model responded with: '{output}'")
  print("-" * 50)
# Out:
# For max_tokens: 50
# The Model responded with: 'Embarking on a space adventure was a dream come true for the crew of the interstellar spacecraft known as Starlight Horizon. As they soared through the vast expanse of the cosmos, they marveled at the beauty of the universe unfolding before them.'
# --------------------------------------------------
# For max_tokens: 100
# The Model responded with: 'As the spaceship soared through the vast darkness of space, the crew marveled at the twinkling stars and swirling galaxies outside their windows. They were on a mission to explore a newly discovered planet on the edge of the galaxy, hoping to uncover secrets of alien life and technology. As they approached the planet's surface, they were met with breathtaking views of towering mountains, shimmering oceans, and colorful forests. But their excitement soon turned to fear as they encountered hostile alien creatures and treacherous terrain.'
# --------------------------------------------------

# %% [markdown]
# ### **Task 2.4**
# *Experiment with Top P, Frequency Penalty, and Presence Penalty: Adjust these parameters to explore their effects on repetition, novelty, and thematic diversity.*

# %%
# TOP_P can be any float number between 0 and 1
TOP_P: float = 0.1
# FREQUENCY_PENALTY can be any float Number between -2.0 and 2.0.
FREQUENCY_PENALTY: float = 0
# PRESENCE_PENALTY  can be any float Number between -2.0 and 2.0.
PRESENCE_PENALTY: float = 0

completion = client.chat.completions.create(
  model=MODEL_NAME,
  top_p=TOP_P,
  frequency_penalty=FREQUENCY_PENALTY,
  presence_penalty=PRESENCE_PENALTY,

  messages=[
    {"role": "user", "content": prompt}
  ]
)
output = completion.choices[0].message.content
print(f"The Model responded with: '{output}'")
# Out:
# The Model responded with: 'The crew of the starship Odyssey embarked on a daring space adventure to explore the uncharted regions of the galaxy. As they traveled through the vast expanse of space, they encountered strange and wondrous alien civilizations, breathtaking celestial phenomena, and treacherous cosmic obstacles. Their journey was fraught with danger and excitement, but they faced each challenge with courage and determination. Along the way, they made new friends, discovered ancient mysteries, and pushed the boundaries of human knowledge. The crew of the Odyssey returned home as heroes, their hearts filled with the thrill of adventure and the wonder of the cosmos.'

# %% [markdown]
# Reflect on how each parameter influenced the model's output. This exercise will enhance your understanding of how to control and guide the AI to achieve results that best fit your objectives.

# %% [markdown]
# ## Part 3: Prompt engineering (15 min)

# %% [markdown]
# Prompt engineering is an art and science of designing inputs that guide Large Language Models (LLMs), such as Generative Pre-trained Transformer (GPT), to produce specific, high-quality responses or outputs. This process is foundational in the field of artificial intelligence because the precision with which we articulate our prompts significantly affects the AI's performance. A well-crafted prompt can lead to outputs that are not only accurate but also creative and contextually relevant, showcasing the model's capabilities to their fullest extent.
#
# ### Engaging with Prompt Engineering
# Before we dive into specific tactics for effective prompt engineering, it's important to understand that the goal is to communicate with the model in its language. This means being clear, direct, and detailed in your requests.
#
# #### Tactics:
# <ul>
#     <li> <b>Include details in your query</b> to get more relevant answers.
#         <details>
#             <summary>Example</summary>
#             Often people ask questions that are too broad or vague. Remember, the AI can't read your mind ;)
#             <br>
#             Your goal is to extract specific information from the AI.
#             <p> <i>Bad:</i> "Tell me about dogs."</p>
#             <p> <i>Good:</i> "Provide a detailed comparison between the adaptability, exercise needs, and temperament of Labrador Retrievers and Border Collies for potential dog owners."</p>
#         </details>
#     </li>
#     <li> <b>Ask the model to adopt a persona</b> for more tailored responses.
#         <details>
#             <summary>Example</summary>
#             Your goal is to make the interaction more engaging or specific.
#             <p> <i>Bad:</i> "Explain quantum physics."</p>
#             <p> <i>Good:</i> "Pretend you're a renowned physicist explaining the concepts of quantum physics to a high school student in a way that's easy to understand."</p>
#         </details>
#     </li>
#     <li> <b>Use delimiters</b> to clearly indicate distinct parts of the input.
#         <details>
#             <summary>Example</summary>
#             Your goal is to organize a multi-part question.
#             <p> <i>Bad:</i> "What is the capital of France and tell me about its history."</p>
#             <p> <i>Good:</i> "Question 1: What is the capital of France? | Question 2: Provide a brief history of the capital."</p>
#         </details>
#     </li>
#     <li> <b>Specify the steps</b> required to complete a task.
#         <details>
#             <summary>Example</summary>
#             Your goal is to get a walkthrough.
#             <p> <i>Bad:</i> "How to bake a cake."</p>
#             <p> <i>Good:</i> "List all the steps necessary to bake a chocolate cake, then create a list of needed ingredients with quantities, and baking time. Before estimating total time needed."</p>
#         </details>
#     </li>
#     <li> <b>Provide examples</b> to illustrate the type of response you're seeking.
#         <details>
#             <summary>Example</summary>
#             Your goal is to clarify your expectations.
#             <p> <i>Bad:</i> "Generate a catchy slogan for my product."</p>
#             <p> <i>Good:</i> "Generate a catchy slogan for my eco-friendly water bottle product. For example, something like 'Hydrate Sustainably' or 'Drink Green, Live Clean'."</p>
#         </details>
#     </li>
#     <li> <b>Specify the desired length</b> of the output to control verbosity.
#         <details>
#             <summary>Example</summary>
#             Your goal is to manage the depth of the response.
#             <p> <i>Bad:</i> "Write an article on climate change."</p>
#             <p> <i>Good:</i> "Write a concise 300-word article on the impacts of climate change on global weather patterns."</p>
#         </details>
#     </li>
# </ul>
#
#
# ### Applying What We've Learned
# Now that we've outlined the key tactics for effective prompt engineering, let's put this knowledge into practice.

# %% [markdown]
# ### **Task 3.1**

# %% [markdown]
# Imagine you're working on the Cogito Project **TutorAI**, a cutting-edge AI tool designed to support students in their study efforts by creating concise, informative flashcards from dense academic texts. Your challenge is to engineer a prompt that instructs the LLM to distill complex material into easy-to-review flashcards, focusing on key concepts, definitions, and examples relevant to an upcoming exam.
#
# * **Extract Key Concepts and Definitions:** The AI must identify and summarize the main ideas and definitions found in a given academic text. This involves discerning the most important points that are crucial for understanding the subject matter.
#
# * **Format the Information for Flashcards:** The output should be structured in a way that is suitable for flashcard creation. Each flashcard will have a term or concept on one side and its definition or explanation on the other side, along with an example if appropriate.
#
# * **Control the Length:** Each flashcard content (term/definition/example) should be concise, aiming for no more than 50 words per side to facilitate quick review and memorization.
#
# This task will test your ability to use detailed queries, specify a structure, and control the output length—all crucial aspects of prompt engineering. Remember, the effectiveness of your prompt will directly influence the quality and relevance of the AI's response. Good luck!

# %%
book_paragraphs: str = """
Chapter 1 - Epic Introduction
Since the dawn of time, humans have tried to define how we think, and this struggle has led us to create artificial intelligence. Historically, four approaches to artificial intelligence have been followed, each described below.

Acting Humanly
If we can't distinguish between a computer and a human, the computer is said to act humanly. The computer's capability to act humanly can be tested by performing a turing test. A computer passes the turing test if a human interrogator cannot tell whether he is communicating with a computer or a person. To pass a turing test, the computer would need to possess the following capabilities:

Natural language processing to enable it to communicate successfully.
Knowledge representation to store what it knows or hears.
Automated reasoning to use the stored information to draw conclusions.
Machine learning to adapt to new circumstances and to detect patterns.

Thinking humanly
To make a computer think like a human, we must know how humans think. The computers ability to think humanly can be determined by comparing the computer's input-output mechanism by the corresponding human behaviour.

Acting Rationally
An agent is something that acts. A rational agent is an agent that does the right thing based on what it knows, its functions, and the surrounding environment; it acts so that it achieves the best expected outcome.

Thinking rationally
Using sound logic rules to reach the right conclusion.

A relevant quote, demonstrating the logical rule of modus ponens: "Socrates is a man; all men are mortal; therefore, Socrates is mortal.
"""

def generate_flashcards_from_paragraphs(paragraph: str) -> str:
  completion = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
      # TODO: Create a prompt or combination of "system" and "user" prompts to achieve tasks objectives
      {"role": "system", "content": "Convert textbook paragraphs into concise question-answer flashcards"},
      {"role": "user", "content": book_paragraphs},
    ]
  )
  return completion.choices[0].message.content

flashcards = generate_flashcards_from_paragraphs(book_paragraphs)
print(f"The Model responded with the following flashcards: \n'{flashcards}'")
# Out:
# The Model responded with the following flashcards:
# 'What is the Turing test used for in the context of artificial intelligence?
# - The Turing test is used to determine if a computer can act humanly by seeing if a human interrogator can distinguish between communicating with a computer or a person.
#
# How is a computer's ability to think humanly evaluated?
# - A computer's ability to think humanly is evaluated by comparing its input-output mechanism to corresponding human behavior.
#
# What defines a rational agent in the context of artificial intelligence?
# - A rational agent is an agent that does the right thing based on what it knows, its functions, and the surrounding environment to achieve the best expected outcome.
#
# How is the concept of thinking rationally defined in artificial intelligence?
# - Thinking rationally in artificial intelligence involves using sound logic rules to reach the right conclusions, as demonstrated by the logical rule of modus ponens in the provided quote.'

# %% [markdown]
# ## Part 4: Embeddings (15 min)

# %%
def create_embedding(prompt: str, model="text-embedding-ada-002") -> list[float]:
    return client.embeddings.create(model=model, input=prompt).data[0].embedding

print(create_embedding("This is an embedding!"))

database: list[list[list[float]], str] = []

# Create embedding-text key-value pairs and add them to the database
corresponding_text_1 = "This is an embedding!"
embedding_1 = create_embedding(corresponding_text_1)
database.append([embedding_1, corresponding_text_1])

corresponding_text_2 = "Sverre is CTO of Cogito NTNU"
embedding_2 = create_embedding(corresponding_text_2)
database.append([embedding_2, corresponding_text_2])
# Out:
# [-0.023320836946368217, 0.0036924658343195915, 0.0025099546182900667, 0.0012706232955679297, -0.010718362405896187, 0.007365168537944555, 0.00589938135817647, -0.014400946907699108, -0.008801310323178768, -0.036733612418174744, 0.01187122892588377, 0.03631199151277542, -0.013089972548186779, -0.0034981255885213614, 0.004015268292278051, 0.017484040930867195, 0.02378198318183422, 0.003939508926123381, 0.0070950682274997234, -0.020580310374498367, -0.01803741604089737, 0.01043508667498827, 0.005425059236586094, -0.012898926623165607, -0.007193885277956724, 0.006495577748864889, 0.014572229236364365, -0.018485387787222862, -0.0017704732017591596, -0.01963166519999504, 0.0022612647153437138, -0.0069040218368172646, -0.011647243052721024, -0.029671482741832733, -0.00385057320818305, -0.00227608741261065, -0.0015736623900011182, -0.02946067415177822, 0.01401885412633419, 0.003071565181016922, 0.013215141370892525, -0.007622092962265015, -0.0031769699417054653, -0.012958216480910778, -0.015902966260910034, 0.006897434126585722, 0.0018824659055098891, -0.013485241681337357, -0.003626587800681591, -0.003919745329767466, 0.03249106556177139, 0.01968436874449253, -0.02806405909359455, -0.00632100086659193, -0.01675938069820404, 0.009664312936365604, -0.012022747658193111, 0.006212302017956972, 0.005523876287043095, -0.020409027114510536, 0.006689918227493763, 0.018972884863615036, -0.02234584279358387, 0.0012714468175545335, -0.014545878395438194, -0.010046405717730522, 0.0035574159119278193, 0.011950282379984856, 0.008913302794098854, 0.006386878900229931, 0.0304093174636364, 0.012813284993171692, -0.009927825070917606, -0.006897434126585722, 0.013070209883153439, 0.0024111373350024223, -0.017128298059105873, -0.004664167296141386, 0.0091043496504426, 0.0003495655255392194, -0.0027767608407884836, -0.03220120072364807, 0.00838627852499485, 0.02496778964996338, 0.0021278616040945053, 0.0027108825743198395, -0.009881710633635521, 0.038420092314481735, -0.005988316610455513, 0.011449608951807022, 0.012793521396815777, 0.005836796946823597, -0.008926479145884514, -0.00041750227683223784, -0.0012376842787489295, 0.035389699041843414, -0.0020488081499934196, 0.021621182560920715, 0.027378926053643227, -0.005398707929998636, 0.0024786624126136303, 0.02388738840818405, -0.012207206338644028, -0.01654857210814953, -0.0332816019654274, -0.006805204786360264, 0.00630453135818243, -0.005461292341351509, 0.02372928149998188, 0.0033021382987499237, -0.009901474229991436, 0.015968844294548035, 0.0005978434928692877, -0.04461263120174408, 0.0036759963259100914, 0.01257612369954586, 0.0046048774383962154, -0.014480000361800194, -0.004716869909316301, -0.023070501163601875, 0.021739764139056206, 0.03868360444903374, -0.014875268563628197, -0.0027405277360230684, 0.02499414049088955, -0.00662733381614089, 0.0014550818596035242, -0.020277271047234535, -0.021911047399044037, -0.007984422147274017, 0.014387770555913448, 0.005042966455221176, 0.009460090659558773, 0.006712975446134806, -0.01928909868001938, 0.028406623750925064, -0.002852520439773798, 0.015428644604980946, -0.03193768858909607, -0.019855650141835213, 0.01816917210817337, 0.015758035704493523, -0.0166408009827137, -0.00028615788323804736, -0.0183404553681612, 0.024256305769085884, -0.004058089107275009, 0.013597234152257442, 0.0015934258699417114, -0.020105987787246704, 0.014335068874061108, -0.005579872522503138, -0.009249281138181686, 0.0055041126906871796, -0.0054876431822776794, 0.03214849904179573, 0.015059727244079113, -0.01687796227633953, -0.014677634462714195, -0.009473267011344433, -0.005635869223624468, 0.01323490496724844, -0.001701301196590066, 0.0003744756686501205, 0.018551265820860863, 0.024032320827245712, 0.009973940439522266, 0.006525223143398762, 0.0004965559928677976, -0.0026878253556787968, -0.002149272011592984, 0.014361419714987278, -0.032780930399894714, 0.0060574887320399284, -0.0182086993008852, -0.0010359326843172312, 0.01182511355727911, -0.008122766390442848, -0.0 ...

# %%
import numpy as np

def cosine_similarity(a: list[float], b: list[float]) -> float:
    """
    Takes 2 vectors a, b and finds how similar they are using the cosine similarity

    Args:
    a (list[float]): A list of floats
    b (list[float]): A list of floats

    Returns:
        The similarity of the two vectors a and b described as a float between 0 and 1

    """
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

def search_docs(query: str, database: list[list[list[float]], str], top_k: int=1):
    """
    Searches the database for the most similar documents to the query

    Args:
        query (str): The query to search for
        database (list[list[list[float]], str]): The database to search in
        top_k (int): The number of documents to return
    Returns:
        A list of the top_k most similar documents to the query
    """
    query_embedding = create_embedding(query)
    results = []
    for (doc_embedding, doc) in database:
        similarity = cosine_similarity(query_embedding, doc_embedding)
        results.append((similarity, doc))
    return sorted(results, reverse=True)[:top_k]

search_docs("Who is the CTO of Cogito?", database)
# Out:
# [(np.float64(0.8882484053164321), 'Sverre is CTO of Cogito NTNU')]

# %% [markdown]
# ### **Task 4.1**
# *Create a new embedding with some text of your choice, and add it to the database. See if you can make the model find it.*
#
# <details>
#     <summary><strong>Hint:</strong></summary>
#       - Look at the previous two cells
# </details>

# %%
corresponding_text_3 = "This is a new test embedding!"
embedding_3 = create_embedding(corresponding_text_3)
database.append([embedding_3, corresponding_text_3])

while True:
  user_input: str = input("What would you like to ask the model: ")

  if user_input == "q":
      print("[SUCCESS] Shut down")
      break

  answer = search_docs(user_input, database, top_k=1)

  print(f"The AI gave the answer: {answer}\n")
# Out:
# What would you like to ask the model: what is this
# The AI gave the answer: [(np.float64(0.7854655386816596), 'This is an embedding!')]
#
# What would you like to ask the model: q
# [SUCCESS] Shut down

# %% [markdown]
# #### Task 5.2
# *Work together with others and create something cool, try to utilize the different lesseons you have learned examples are:*
# * Create external API access some live data
# * Create more complex math operations to do calculus
# * Create bash scripts to create folders or organize a folder
# * Access a database for getting info

# %%
# TODO: Copy relevant code from this notebook and create something

# %% [markdown]
# ### Running local LLMs
# For those interested in experimenting with Large Language Models (LLMs) without incurring the costs associated with API calls to services like OpenAI's, or dealing with sensitive or proprietary data, running pre-trained models on your own hardware presents a viable alternative. The open-source community, particularly [Hugging Face's](https://huggingface.co/models) Transformers library, offers access to a wide range of models, including some developed by leading tech companies.
#
# One of the standout models available is Google's FLAN-T5-XL, part of the T5 (Text-to-Text Transfer Transformer) family, which has been fine-tuned for a broad set of tasks. This model combines the flexibility of T5's architecture with training on a mixture of supervised and unsupervised tasks, making it particularly adept at understanding and generating human-like text.
#
# To get started with using FLAN-T5-XL or any other model from the Transformers library, you will need to install the necessary packages and understand how to load and interact with the model. Below is a basic Python script that demonstrates how to set up and use FLAN-T5-XL for generating text based on input prompts:
# ```python
# import sys
# from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, GenerationConfig
#
# line = 'What is the value of being accepted into Cogito NTNU, Norway's largest technical AI student organisation, in the middle of an AI revolution?'
#
# model_name = 'google/flan-t5-xl'
# tokenizer = AutoTokenizer.from_pretrained(model_name)
# model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
#
# config = GenerationConfig(max_new_tokens=200)
# for line in sys.stdin:
#     tokens = tokenizer(line, return_tensors="pt")
#     outputs = model.generate(**tokens, generation_config=config)
#     print(tokenizer.batch_decode(outputs, skip_special_tokens=True))
# ```

# %% [markdown]
# ### Context windows
#
# The context window refers to the maximum amount of text (measured in tokens) the model can consider at one time when generating responses or performing tasks. This limit is intrinsic to the model's architecture and significantly influences how we design prompts and interpret model outputs.
#
# #### Significance of the Context Window
# The size of the context window determines how much information the model can "see" and use at any given moment. For example, GPT-3 has a context window of 2048 tokens. This means it can consider up to 2048 tokens of preceding text to generate its responses. The implications are twofold:
#
# * **Prompt Design:** When crafting prompts for an LLM, it's vital to ensure that the most relevant information is within the model's context window. Information beyond this limit won't influence the model's output, emphasizing the need for concise and focused prompt design.
#
# * **Sequential Tasks:** For tasks requiring more information than the context window allows, you may need to design a series of prompts that build on each other, ensuring each segment of the task remains within the model's view.
#
# While advancements have led to models supporting context windows surpassing 100,000 tokens (gpt-4 and other open source ones), challenges persist. Specifically, such models tend to focus on the beginning and end of the provided text, potentially underutilizing the middle portion. This is know as [lost in the middle](https://arxiv.org/pdf/2307.03172.pdf).
#
# #### New insights by a Operative System inspired model
# [MemGPT](https://memgpt.readme.io/docs/index) introduces a strategic approach to memory management, organized around two core concepts relevant to understanding context windows in LLMs:
#
# * **Memory Hierarchy:** It segments memory into two types: a "main context" analogous to RAM, which is smaller and faster, and an "external context" similar to disk storage, which is larger but slower. This structure necessitates the deliberate transfer of information between these contexts, using virtual memory.
#
# * **Process Management:** Similar to an operating system's role in managing tasks, MemGPT regulates the flow of information between the memory segments, the LLM, and users, ensuring efficient handling of processes.

# %% [markdown]
# ### Fine-tuning Large Language Models
# Fine-tuning is a process that adjusts a pre-trained model to a specific task or dataset, enhancing its ability to perform on tasks it wasn't specifically trained for initially. This method leverages the general understanding that the model has developed during its initial training phase, applying it to a more focused domain or problem set. Fine-tuning can significantly improve the performance of LLMs on specialized tasks, making it a powerful tool for developers and researchers.
#
# #### Why Fine-tune?
# Customization: Tailors the model to understand and generate responses based on specific jargon, styles, or formats unique to your dataset.
# Improved Performance: Enhances the model's accuracy and efficiency on tasks that may differ from the data it was originally trained on.
# Cost-Effectiveness: Utilizes the foundational knowledge the model has gained, reducing the need for training from scratch on vast datasets.
#
# 1. **How to Fine-tune an LLM:**
# Select a Pre-trained Model: Choose a model that closely aligns with your task in terms of language and domain. Models available on platforms like Hugging Face offer a good starting point.
#
# 2. **Prepare Your Dataset:** Your dataset should be representative of the task at hand and formatted in a way that the model can understand. It typically involves splitting the data into training, validation, and test sets.
#
# 3. **Customize Training Parameters:** Adjust parameters such as learning rate, batch size, and the number of epochs to balance between retaining learned knowledge and adapting to the new dataset.
#
# 4. **Train the Model:** Use a suitable environment and framework, like PyTorch or TensorFlow, along with Hugging Face's Transformers library, to fine-tune the model on your dataset.
#
# 5. **Evaluate and Iterate:** Test the model's performance on a separate validation set, and iteratively adjust your approach based on the results.
#
# An example of this using OpenAI can be found in the Cogito Project [MarketingAI](https://github.com/CogitoNTNU/MarketingAI/blob/main/src/fine_tuning/fine_tuning_job.py)

# %% [markdown]
# ### Leveraging OpenAI Across Diverse Programming Environments
# While this course primarily focuses on Python to interact with OpenAI's models. Thera are other supported languages. Supported languages include, but are not limited to, TypeScript/JavaScript, Java, C#, Go, C++, and PHP, alongside others like Clojure, Kotlin, Ruby, Rust, and Scala. This wide-ranging support extends the potential of OpenAI's AI models to virtually any software development domain, from web development and mobile applications to enterprise solutions and beyond.
#
# [Read more at OpenAI Docs](https://platform.openai.com/docs/libraries/community-libraries)
